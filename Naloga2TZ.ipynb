# %% [markdown]
# <a href="https://colab.research.google.com/github/klarcika/DSR/blob/main/Naloga2TZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#naložite v notebook ali .py dokument
#izpišite koliko vrstic in stolpcev je v tej podatkovni zbirki
#prikažite katerih tipov so podatki, shranjeni v tej datoteki
#izpišite prve 4 vrstice
#izpišite zadnjih 5 vrstic
#izpišite opisno statistiko za vse številske stolpce

# %%
dframe= pd.read_csv("diabetes_prediction.csv",index_col="gender",decimal="," )

# %%
dframe.shape
# Out:
# (5998, 8)

# %%
dframe.describe
# Out:
# <bound method NDFrame.describe of          age  hypertension  heart_disease smoking_history    bmi HbA1c_level  \
# gender
# Female  80.0             0              1           never  25.19         6.6
# Female  54.0             0              0         No Info  27.32         6.6
# Male    28.0             0              0           never  27.32         5.7
# Female  36.0             0              0         current  23.45         5.0
# Male    76.0             1              1         current  20.14         4.8
# ...      ...           ...            ...             ...    ...         ...
# Male    19.0             0              0         No Info  27.32         6.5
# Male    38.0             0              0         No Info  27.32         6.6
# Male    66.0             0              1         No Info  29.67         5.0
# Female  80.0             0              0           never  27.81         8.8
# Female  80.0             0              0           never   25.0         4.5
#
#        blood_glucose_level  diabetes
# gender
# Female               140.0         0
# Female                80.0         0
# Male                 158.0         0
# Female               155.0         0
# Male                 155.0         0
# ...                    ...       ...
# Male                 140.0         0
# Male                 145.0         0
# Male                  85.0         0
# Female               240.0         1
# Female               160.0         0
#
# [5998 rows x 8 columns]>

# %%
dframe.head(4)
# Out:
#          age  hypertension  heart_disease smoking_history    bmi HbA1c_level  \
# gender
# Female  80.0             0              1           never  25.19         6.6
# Female  54.0             0              0         No Info  27.32         6.6
# Male    28.0             0              0           never  27.32         5.7
# Female  36.0             0              0         current  23.45         5.0
#
#        blood_glucose_level  diabetes
# gender
# Female               140.0         0
# Female                80.0         0
# Male                 158.0         0
# Female               155.0         0

# %%
dframe.tail(5)
# Out:
#          age  hypertension  heart_disease smoking_history    bmi HbA1c_level  \
# gender
# Male    19.0             0              0         No Info  27.32         6.5
# Male    38.0             0              0         No Info  27.32         6.6
# Male    66.0             0              1         No Info  29.67         5.0
# Female  80.0             0              0           never  27.81         8.8
# Female  80.0             0              0           never   25.0         4.5
#
#        blood_glucose_level  diabetes
# gender
# Male                 140.0         0
# Male                 145.0         0
# Male                  85.0         0
# Female               240.0         1
# Female               160.0         0

# %%
import seaborn as sns

# %%
sns.displot(dframe.age)

# %%
sns.displot(dframe.hypertension)

# %%
sns.displot(dframe.blood_glucose_level)

# %%
sns.displot(dframe.bmi)

# %% [markdown]
# NOVI SKLOP

# %%
df_rank= pd.read_csv("university_rank_2020.csv",index_col="University", decimal=",")

# %%
df_other= pd.read_csv("university_rank_other.csv", decimal=" ")

# %%
df_student= pd.read_excel("university_rank_students.xlsx",index_col=0, sheet_name=0)

# %%
df=pd.concat([df_rank, df_other,df_student], axis=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-38-45d1b00423d2> in <cell line: 1>()
# ----> 1 df=pd.concat([df_rank, df_other,df_student], axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379     )
#     380
# --> 381     return op.get_result()
#     382
#     383
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     610                     obj_labels = obj.axes[1 - ax]
#     611                     if not new_labels.equals(obj_labels):
# --> 612                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     613
#     614                 mgrs_indexers.append((obj._mgr, indexers))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3902
#    3903         if not self._index_as_unique:
# -> 3904             raise InvalidIndexError(self._requires_unique_msg)
#    3905
#    3906         if len(target) == 0:
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects
